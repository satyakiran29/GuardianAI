# %%
import pandas as pd

df = pd.read_csv('/content/Woman_Safety_Dataset_Management.csv')
display(df.head())
# Out:
#                             incident_id     city           area   latitude  \
# 0  2b63f176-a5c9-4ac5-adbb-b81c14754ec4  Kolkata    Park Street  22.587501
# 1  ef4ba791-e5b5-4146-a3bb-c63e5d695e7c  Kolkata          Garia  22.565575
# 2  6db79d9c-62d4-4c74-a2f2-295297dbc083   Bhopal          Kolar  23.242474
# 3  84fa6f88-339e-44b9-896a-6a548b8466c6   Mumbai          Kurla  18.997624
# 4  9e5035a9-0d9b-40fc-a1e8-21702c65096e   Jaipur  Malviya Nagar  26.899559
#
#    longitude         crime_type  crime_count time_of_day  lighting_score  \
# 0  88.359752  Domestic Violence           23   Afternoon            2.26
# 1  88.356876            Assault            4     Morning            1.84
# 2  77.396845       Verbal Abuse           25   Afternoon            5.04
# 3  72.906211    Chain Snatching           19   Afternoon            2.94
# 4  75.765028    Chain Snatching           56     Evening            6.43
#
#    police_station_distance_km  crowd_density weather_condition  safety_score  \
# 0                        1.00            768            Stormy          0.85
# 1                        2.01            626             Clear          0.92
# 2                        2.37            900             Clear          0.89
# 3                        6.16            114             Clear          0.58
# 4                        6.50            757             Humid          0.42
#
#   risk_level   incident_timestamp
# 0        Low  2025-05-14 12:40:25
# 1        Low  2024-11-02 08:14:54
# 2        Low  2026-01-27 03:45:27
# 3     Medium  2026-02-09 17:34:04
# 4       High  2025-02-16 06:47:57

# %%
print(df.info())
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   incident_id                 20000 non-null  object
#  1   city                        20000 non-null  object
#  2   area                        20000 non-null  object
#  3   latitude                    20000 non-null  float64
#  4   longitude                   20000 non-null  float64
#  5   crime_type                  20000 non-null  object
#  6   crime_count                 20000 non-null  int64
#  7   time_of_day                 20000 non-null  object
#  8   lighting_score              20000 non-null  float64
#  9   police_station_distance_km  20000 non-null  float64
#  10  crowd_density               20000 non-null  int64
#  11  weather_condition           20000 non-null  object
#  12  safety_score                20000 non-null  float64
#  13  risk_level                  20000 non-null  object
#  14  incident_timestamp          20000 non-null  object
# dtypes: float64(5), int64(2), object(8)
# memory usage: 2.3+ MB
# None
# (20000, 15)

# %%
display(df.describe())
# Out:
#            latitude     longitude   crime_count  lighting_score  \
# count  20000.000000  20000.000000  20000.000000    20000.000000
# mean      21.625279     79.419284     32.356850        5.493725
# std        5.430797      4.313909     17.146166        2.592954
# min       12.874962     72.764977      0.000000        1.000000
# 25%       17.385593     77.207536     18.000000        3.220000
# 50%       23.188318     77.669767     32.000000        5.500000
# 75%       26.842789     80.949044     46.000000        7.750000
# max       28.718786     88.460186     85.000000       10.000000
#
#        police_station_distance_km  crowd_density  safety_score
# count                20000.000000   20000.000000  20000.000000
# mean                     4.116744     505.148050      0.714330
# std                      2.233540     284.978533      0.219358
# min                      0.200000      10.000000      0.000000
# 25%                      2.220000     259.000000      0.560000
# 50%                      4.110000     502.000000      0.730000
# 75%                      6.040000     750.000000      0.900000
# max                      8.000000    1000.000000      1.000000

# %%
df.shape
# Out:
# (20000, 15)

# %%
df.columns
# Out:
# Index(['incident_id', 'city', 'area', 'latitude', 'longitude', 'crime_type',
#        'crime_count', 'time_of_day', 'lighting_score',
#        'police_station_distance_km', 'crowd_density', 'weather_condition',
#        'safety_score', 'risk_level', 'incident_timestamp'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# incident_id                   0
# city                          0
# area                          0
# latitude                      0
# longitude                     0
# crime_type                    0
# crime_count                   0
# time_of_day                   0
# lighting_score                0
# police_station_distance_km    0
# crowd_density                 0
# weather_condition             0
# safety_score                  0
# risk_level                    0
# incident_timestamp            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["city"].value_counts()
# Out:
# city
# Bhopal       2043
# Chennai      2026
# Jaipur       2021
# Mumbai       2019
# Lucknow      2016
# Patna        2015
# Kolkata      2014
# Bengaluru    2000
# Delhi        1925
# Hyderabad    1921
# Name: count, dtype: int64

# %%
df["city"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %%
df["crime_type"].value_counts()
# Out:
# crime_type
# Night Safety Complaint    2047
# Cyber Crime               2045
# Harassment                2036
# Stalking                  2036
# Verbal Abuse              2000
# Assault                   1999
# Kidnapping                1992
# Unsafe Transport          1978
# Chain Snatching           1938
# Domestic Violence         1929
# Name: count, dtype: int64

# %%
df["risk_level"].value_counts()
# Out:
# risk_level
# Low         9301
# Medium      6940
# High        3260
# Critical     499
# Name: count, dtype: int64

# %%
df["time_of_day"].value_counts()
# Out:
# time_of_day
# Night         4061
# Evening       4029
# Morning       3987
# Afternoon     3978
# Late Night    3945
# Name: count, dtype: int64

# %%
df["weather_condition"].value_counts()
# Out:
# weather_condition
# Clear     4054
# Stormy    4032
# Rainy     4016
# Humid     3971
# Foggy     3927
# Name: count, dtype: int64

# %%
df["safety_score"].mean()
# Out:
# np.float64(0.7143305)

# %%
df.groupby("area")["crime_count"].sum().sort_values(ascending=False)
# Out:
# area
# TT Nagar           14244
# T Nagar            14076
# Indiranagar        14021
# Kukatpally         13877
# Habibganj          13791
# Vaishali Nagar     13778
# Hazratganj         13768
# Arera Colony       13757
# Koramangala        13709
# Tambaram           13639
# Powai              13414
# MP Nagar           13351
# Park Street        13289
# Gomti Nagar        13205
# Danapur            13166
# Dadar              13114
# Indira Nagar       13113
# Bandra             13080
# Mansarovar         13056
# Salt Lake          13047
# Andheri            12998
# Howrah             12978
# C Scheme           12952
# Kankarbagh         12901
# Rajendra Nagar     12850
# Banjara Hills      12842
# Patliputra         12831
# Whitefield         12818
# Chowk              12809
# Lajpat Nagar       12794
# Velachery          12784
# Malviya Nagar      12759
# Electronic City    12727
# Garia              12717
# Kolar              12700
# Dum Dum            12699
# Saket              12658
# Amer               12603
# Dwarka             12535
# Gachibowli         12489
# Boring Road        12479
# Adyar              12406
# Yelahanka          12335
# Anna Nagar         12280
# Secunderabad       12211
# Aliganj            12204
# Kurla              12134
# Rohini             12102
# Karol Bagh         11666
# Madhapur           11381
# Name: crime_count, dtype: int64

# %%
df.groupby("city")["crime_count"].sum().sort_values(ascending=False)
# Out:
# city
# Bhopal       67843
# Bengaluru    65610
# Chennai      65185
# Jaipur       65148
# Lucknow      65099
# Mumbai       64740
# Kolkata      64730
# Patna        64227
# Hyderabad    62800
# Delhi        61755
# Name: crime_count, dtype: int64

# %%
df[["lighting_score","safety_score"]].corr()
# Out:
#                 lighting_score  safety_score
# lighting_score        1.000000      0.526788
# safety_score          0.526788      1.000000

# %%
df.groupby("risk_level")["police_station_distance_km"].mean()
# Out:
# risk_level
# Critical    7.025431
# High        5.921457
# Low         2.935913
# Medium      4.642408
# Name: police_station_distance_km, dtype: float64

# %%
df.groupby("risk_level")["crowd_density"].mean()
# Out:
# risk_level
# Critical    509.194389
# High        513.742331
# Low         504.383937
# Medium      501.844092
# Name: crowd_density, dtype: float64

# %%
df["crime_count"].describe()
# Out:
# count    20000.000000
# mean        32.356850
# std         17.146166
# min          0.000000
# 25%         18.000000
# 50%         32.000000
# 75%         46.000000
# max         85.000000
# Name: crime_count, dtype: float64

# %%
df["incident_timestamp"] = pd.to_datetime(df["incident_timestamp"])

df["Month"] = df["incident_timestamp"].dt.month_name()

# %%
df.groupby("Month")["crime_count"].sum()
# Out:
# Month
# April        50487
# August       54570
# December     53695
# February     49842
# January      53357
# July         57749
# June         51002
# March        55229
# May          59012
# November     53958
# October      54961
# September    53275
# Name: crime_count, dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                             latitude  longitude  crime_count  lighting_score  \
# latitude                    1.000000   0.131835    -0.006918        0.005251
# longitude                   0.131835   1.000000    -0.006575        0.005505
# crime_count                -0.006918  -0.006575     1.000000       -0.013968
# lighting_score              0.005251   0.005505    -0.013968        1.000000
# police_station_distance_km  0.008204   0.002534    -0.001181       -0.005239
# crowd_density               0.009306   0.002273     0.005744        0.006342
# safety_score                0.002129   0.003810    -0.581070        0.526788
#
#                             police_station_distance_km  crowd_density  \
# latitude                                      0.008204       0.009306
# longitude                                     0.002534       0.002273
# crime_count                                  -0.001181       0.005744
# lighting_score                               -0.005239       0.006342
# police_station_distance_km                    1.000000       0.014400
# crowd_density                                 0.014400       1.000000
# safety_score                                 -0.599331      -0.009363
#
#                             safety_score
# latitude                        0.002129
# longitude                       0.003810
# crime_count                    -0.581070
# lighting_score                  0.526788
# police_station_distance_km     -0.599331
# crowd_density                  -0.009363
# safety_score                    1.000000

# %%
df["safety_score"].hist()
# Out:
# <Axes: >

# %%
df[df["risk_level"]=="High"]
# Out:
#                                 incident_id       city           area  \
# 4      9e5035a9-0d9b-40fc-a1e8-21702c65096e     Jaipur  Malviya Nagar
# 10     af56eaff-1bda-4226-bcf9-044b2d0c4847      Patna        Danapur
# 11     c2847f2b-9575-4f18-86a3-5c537c0900a4  Bengaluru    Indiranagar
# 13     9cfcd964-84a4-4209-87af-6bfe0eab1a6b     Mumbai         Bandra
# 19     e59bc447-0a0f-4df6-a336-4c8edb348a69    Lucknow     Hazratganj
# ...                                     ...        ...            ...
# 19966  006c2d87-c927-49b1-b805-974fe063fb53      Patna    Boring Road
# 19975  10ed58bb-57ed-4627-bbee-946aef110a20     Mumbai         Bandra
# 19980  d5c9bda2-b8c6-4149-bd1c-d31a4b77734d    Lucknow    Gomti Nagar
# 19981  45f96a69-99f6-474b-b719-0dd38f3732dc  Bengaluru     Whitefield
# 19989  d2a2b53e-5325-480a-8d22-f0091e8b638a  Bengaluru      Yelahanka
#
#         latitude  longitude       crime_type  crime_count time_of_day  \
# 4      26.899559  75.765028  Chain Snatching           56     Evening
# 10     25.590631  85.128567       Kidnapping           44       Night
# 11     12.957781  77.626314       Kidnapping           47  Late Night
# 13     19.106930  72.905638          Assault           49     Morning
# 19     26.849311  80.937230     Verbal Abuse           50   Afternoon
# ...          ...        ...              ...          ...         ...
# 19966  25.593163  85.138275     Verbal Abuse           65   Afternoon
# 19975  19.023407  72.886710     Verbal Abuse           28  Late Night
# 19980  26.790892  80.941648         Stalking           43       Night
# 19981  12.947099  77.687188       Harassment           42  Late Night
# 19989  12.984167  77.575711       Kidnapping           60     Evening
#
#        lighting_score  police_station_distance_km  crowd_density  \
# 4                6.43                        6.50            757
# 10               4.56                        7.33            479
# 11               5.85                        6.03            448
# 13               4.46                        4.85            489
# 19               2.16                        3.91            572
# ...               ...                         ...            ...
# 19966            3.96                        4.45            457
# 19975            1.64                        6.97            431
# 19980            1.09                        4.87            268
# 19981            3.80                        7.95            274
# 19989            1.66                        2.45            253
#
#       weather_condition  safety_score risk_level  incident_timestamp  \
# 4                 Humid          0.42       High 2025-02-16 06:47:57
# 10                Rainy          0.37       High 2025-05-12 17:26:28
# 11               Stormy          0.50       High 2025-01-30 19:02:11
# 13               Stormy          0.49       High 2025-05-21 06:54:57
# 19                Rainy          0.43       High 2024-06-16 11:27:23
# ...                 ...           ...        ...                 ...
# 19966             Rainy          0.36       High 2024-09-05 22:56:22
# 19975             Clear          0.38       High 2025-07-24 20:13:32
# 19980             Clear          0.37       High 2025-04-07 04:14:36
# 19981             Humid          0.31       High 2026-01-08 18:49:00
# 19989             Foggy          0.42       High 2024-10-14 02:02:25
#
#            Month
# 4       February
# 10           May
# 11       January
# 13           May
# 19          June
# ...          ...
# 19966  September
# 19975       July
# 19980      April
# 19981    January
# 19989    October
#
# [3260 rows x 16 columns]
