# %%
import plotly.express as px #pip install plotly
import pandas as pd

df = pd.read_csv("Woman_Safety_Dataset_Management.csv")

fig = px.line(
    df,
    x="city",
    y="crime_count",
    title="cimes per city"
)

fig.show()

# %%
import pandas as pd
import plotly.express as px

# Convert timestamp to datetime
df["incident_timestamp"] = pd.to_datetime(df["incident_timestamp"])

fig = px.line(
    df.sort_values("incident_timestamp"),
    x="incident_timestamp",
    y=["crime_count", "safety_score"],
    title="Crime Count and Safety Score Over Time",
    markers=True
)

fig.show()

# %%
import plotly.express as px #pip install plotly
import pandas as pd

df = pd.read_csv("Woman_Safety_Dataset_Management.csv")
city_df = (
    df.groupby("city", as_index=False)["crime_count"]
      .mean()
)
fig = px.line(
    city_df,
    x="city",
    y="crime_count",
    color_discrete_sequence=["red"]
)

fig.show()

# %%
import plotly.express as px

city_df = (
    df.groupby("city", as_index=False)["crime_count"]
      .mean()
)

fig = px.line(
    city_df,
    x="city",
    y="crime_count",
    markers=True,
    title="Average Crime Count by City"
)

fig.show()

# %%
import plotly.express as px

city_df = (
    df.groupby("city", as_index=False)["crime_count"]
      .mean()
)

fig = px.scatter(
    city_df,
    x="city",
    y="crime_count",
    
    title="Average Crime Count by City"
)

fig.show()

# %%
import plotly.express as px

city_df = (
    df.groupby("city", as_index=False)["crime_count"]
      .mean()
)
fig = px.bar(
    city_df,
    x="city",
    y="crime_count",
    
    title="Average Crime Count by City"
)

fig.show()

# %%
import plotly.express as px

city_df = (
    df.groupby("city", as_index=False)["crime_count"]
      .mean()
)
fig = px.pie(
    city_df,
    values="crime_count",
    names="city",
    title="Average Crime Count by City"
)

fig.show()

# %%
import plotly.express as px

city_df = (
    df.groupby("city", as_index=False)["crime_count"]
      .mean()
)
fig = px.pie(
    city_df,
    values="crime_count",
    names="city",
    hole=0.5,
    title="Average Crime Count by City"
)

fig.show()

# %%
city_df = (
    df.groupby("city", as_index=False)["crime_count"]
      .mean()
)
fig = px.histogram(
    city_df,
    x="crime_count",
    title="Average Crime Count by City"
)

fig.show()

# %%
import plotly.express as px

city_df = (
    df.groupby("city", as_index=False)["crime_count"]
      .mean()
)
fig = px.funnel(

    city_df,
    x="crime_count",
    y="city",
    
    title="Average Crime Count by City"
)

fig.show()

# %%
import plotly.express as px

city_df = (
    df.groupby("city", as_index=False)["crime_count"]
      .mean()
)
fig = px.area(

    city_df,
    x="crime_count",
    y="city",
    
    title="Average Crime Count by City"
)

fig.show()

# %%
import plotly.express as px

city_df = (
    df.groupby("city", as_index=False)["crime_count"]
      .mean()
)
fig = px.violin(

    city_df,
    x="crime_count",
  
    
    title="Average Crime Count by City"
)

fig.show()

# %%
import plotly.express as px

city_df = (
    df.groupby("city", as_index=False)["crime_count"]
      .mean()
)
fig = px.violin(

    city_df,
    x="city",
  
    
    title="Average Crime Count by City"
)

fig.show()

# %%
import plotly.express as px

fig = px.sunburst(
    df,
    path=["city", "crime_type"],
    values="crime_count",
    title="Crime Distribution by City and Crime Type"
)

fig.show()

# %%
import plotly.express as px

fig = px.treemap(
    df,
    path=["city", "crime_type"],
    values="crime_count",
    title="Crime Distribution by City and Crime Type"
)

fig.show()

# %%
city_df = (
    df.groupby("city", as_index=False)["crime_count"]
      .mean()
)
fig = px.scatter_matrix(city_df)

fig.show()
