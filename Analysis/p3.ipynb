# %%
from sklearn.preprocessing import LabelEncoder

import pandas as pd

df = pd.read_csv("Woman_Safety_Dataset_Management.csv")

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

df = pd.read_csv("Woman_Safety_Dataset_Management(4).csv")

imputer = SimpleImputer(strategy="mean")

df[["crime_count", "crowd_density"]] = imputer.fit_transform(
    df[["crime_count", "crowd_density"]]
)

print(df[["crime_count", "crowd_density"]].isnull().sum())

# %%
print(df)
# Out:
#                                 incident_id     city           area  \
# 0      2b63f176-a5c9-4ac5-adbb-b81c14754ec4  Kolkata    Park Street
# 1      ef4ba791-e5b5-4146-a3bb-c63e5d695e7c  Kolkata          Garia
# 2      6db79d9c-62d4-4c74-a2f2-295297dbc083   Bhopal          Kolar
# 3      84fa6f88-339e-44b9-896a-6a548b8466c6   Mumbai          Kurla
# 4      9e5035a9-0d9b-40fc-a1e8-21702c65096e   Jaipur  Malviya Nagar
# ...                                     ...      ...            ...
# 19995  75feb8be-38ed-4696-8a9a-d2c92cf07c8b  Chennai        T Nagar
# 19996  3a471ef9-72e6-422c-aa6b-1336b4c4b57a   Mumbai          Powai
# 19997  5ab3e4e3-77a6-49cc-924a-898e31eb7676    Patna     Patliputra
# 19998  bd8ad7fb-2488-40ab-8c1b-eafab004f685   Bhopal      Habibganj
# 19999  648e2297-f438-4f95-b1f7-4a1c4a504d59  Kolkata         Howrah
#
#         latitude  longitude         crime_type  crime_count time_of_day  \
# 0      22.587501  88.359752  Domestic Violence         23.0   Afternoon
# ...
